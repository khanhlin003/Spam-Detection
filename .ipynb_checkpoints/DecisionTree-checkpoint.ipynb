# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
def visualize_preds(table, y_true, y_pred, title):
    scores = []
    f = plt.figure(figsize = (8,8))
    cf = confusion_matrix(y_true, y_pred)
    sb.heatmap(cf, fmt='.0f', annot=True)

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    scores.append(accuracy)
    scores.append(precision)
    scores.append(recall)
    scores.append(f1)
    scores = pd.DataFrame(scores)
    table = pd.concat([table,scores], axis = 1)

    stats_text = "\n\nAccuracy={:0.2f}\nPrecision={:0.2f}\nRecall={:0.2f}\nF1 Score={:0.2f}".format(
        accuracy, precision, recall, f1)

    plt.xlabel('Predicted' + stats_text)
    plt.ylabel('Actual')
    plt.title(title)

    return table

# %%
def evaluate_dt(df_train, df_test):
    # Split the data into features and target variable
    column_names = list(df_train.columns[:-1])
    y_train = df_train['Label'].astype('category')
    X_train = df_train[column_names]

    y_test = df_test['Label'].astype('category')
    X_test = df_test[column_names]

    # Train a decision tree classifier
    dectree = DecisionTreeClassifier()
    dectree.fit(X_train, y_train)

    # Make predictions on the training and test data
    y_train_pred = dectree.predict(X_train)
    y_test_pred = dectree.predict(X_test)

    # Initialize empty DataFrames for storing the metrics
    train_metrics_table = pd.DataFrame()
    test_metrics_table = pd.DataFrame()

    # Call the visualize_preds function to plot the confusion matrix and calculate metrics for both training and test datasets

    train_metrics_table = visualize_preds(train_metrics_table, y_train, y_train_pred, "Decision Tree Classifier - Training Data")
    
    test_metrics_table = visualize_preds(test_metrics_table, y_test, y_test_pred, "Decision Tree Classifier - Test Data")

    # Combine the metrics tables for training and test datasets
    metrics_table = pd.concat([train_metrics_table, test_metrics_table], axis=1)
    metrics_table.columns = ['Training', 'Test']
    metrics_table.index = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

    return dectree, metrics_table

# %%
def visual_dt(df_train, df_test):
    # Split the data into features and target variable
    column_names = list(df_train.columns[:-1])
    y_train = df_train['Label'].astype('category')
    X_train = df_train[column_names]

    y_test = df_test['Label'].astype('category')
    X_test = df_test[column_names]

    # Train a decision tree classifier
    dectree = DecisionTreeClassifier()
    dectree.fit(X_train, y_train)

    # Visualize the decision tree for the training data
    print("Training Data:")
    plt.figure(figsize=(20,10))
    plot_tree(dectree, filled=True, max_depth=8)
    plt.title("Decision Tree Classifier - Training Data")
    plt.show()

    # Visualize the decision tree for the test data
    print("\nTest Data:")
    plt.figure(figsize=(20,10))
    plot_tree(dectree, filled=True, max_depth=8)
    plt.title("Decision Tree Classifier - Test Data")
    plt.show()

    return dectree

# %%
df_oversampled = pd.read_csv("Dataset/oversampled_train.csv")
df_smote_tomek = pd.read_csv("Dataset/smote_tomek_train.csv")
df_smoteen = pd.read_csv("Dataset/smoteenn_train.csv")
df_undersampled = pd.read_csv("Dataset/undersampled_train.csv")
df_test = pd.read_csv("Dataset/test_data.csv")

# %% [markdown]
# # Decision Tree Classification using Oversampled Dataset

# %%
visual_dt(df_oversampled,df_test)
# Out:
# Training Data:
# Test Data:
# DecisionTreeClassifier()

# %%
print("Evaluating decision tree on oversampled dataset:")
evaluate_dt(df_oversampled,df_test)
# Out:
# Evaluating decision tree on oversampled dataset:
# (DecisionTreeClassifier(),
#             Training      Test
#  Accuracy   0.973135  0.920773
#  Precision  0.953427  0.802985
#  Recall     0.994867  0.943860
#  F1 Score   0.973706  0.867742)

# %% [markdown]
# # Decision Tree Classification using SmoteTomek Dataset

# %%
visual_dt(df_smote_tomek,df_test)
# Out:
# Training Data:
# Test Data:
# DecisionTreeClassifier()

# %%
print("Evaluating decision tree on SMOTE-TOMEK dataset:")
evaluate_dt(df_smote_tomek,df_test)
# Out:
# Evaluating decision tree on SMOTE-TOMEK dataset:
# (DecisionTreeClassifier(),
#             Training      Test
#  Accuracy   0.973459  0.917874
#  Precision  0.954321  0.804878
#  Recall     0.994521  0.926316
#  F1 Score   0.974006  0.861338)

# %% [markdown]
# # Decision Tree Classification using SMOTEENN Dataset

# %%
visual_dt(df_smoteen,df_test)
# Out:
# Training Data:
# Test Data:
# DecisionTreeClassifier()

# %%
print("Evaluating decision tree on SMOTEENN dataset:")
evaluate_dt(df_smoteen,df_test)
# Out:
# Evaluating decision tree on SMOTEENN dataset:
# (DecisionTreeClassifier(),
#             Training      Test
#  Accuracy        1.0  0.889855
#  Precision       1.0  0.732970
#  Recall          1.0  0.943860
#  F1 Score        1.0  0.825153)

# %% [markdown]
# # Overfitting!

# %% [markdown]
# SMOTEENN model has 100% accuracy on the training data which might be due to overfitting of the data, which means it has learned the training data too well, including the noise and peculiarities that are not generalizable to new, unseen data. As a result, the model may perform poorly on the test data or real-world data as seen by the 89% accuracy on test model.

# %% [markdown]
# # Decision Tree Classification using UnderSampled Dataset

# %%
visual_dt(df_undersampled,df_test)
# Out:
# Training Data:
# Test Data:
# DecisionTreeClassifier()

# %%
print("Evaluating decision tree on undersampled dataset:")
evaluate_dt(df_undersampled,df_test)
# Out:
# Evaluating decision tree on undersampled dataset:
# (DecisionTreeClassifier(),
#             Training      Test
#  Accuracy   0.973135  0.921739
#  Precision  0.953427  0.805389
#  Recall     0.994867  0.943860
#  F1 Score   0.973706  0.869144)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

def compare_results_2(df_oversampled, df_smote_tomek, df_smoteen, df_undersampled):
    # Split the data into features and target variable
    column_names = list(df_oversampled.columns[:-1])
    y_train = df_oversampled['Label'].astype('category')
    X_train = df_oversampled[column_names]

    # Train a decision tree classifier on each dataset
    results = []
    for df in [df_oversampled, df_smote_tomek, df_smoteen, df_undersampled]:
        column_names = list(df.columns[:-1])
        y_train = df['Label'].astype('category')
        X_train = df[column_names]
        dectree = DecisionTreeClassifier()
        dectree.fit(X_train, y_train)
        y_train_pred = dectree.predict(X_train)
        accuracy = accuracy_score(y_train, y_train_pred)
        results.append(accuracy)

    # Rank the datasets based on their accuracy scores
    rankings = sorted(range(len(results)), key=lambda k: results[k], reverse=True)

    # Print the rankings
    print("Rankings 1st is best while 4th is worst:")
    for i, r in enumerate(rankings):
        if r == 0:
            print("{}. Oversampled ({:.2f}%)".format(i+1, results[r]*100))
        elif r == 1:
            print("{}. SMOTE-TOMEK ({:.2f}%)".format(i+1, results[r]*100))
        elif r == 2:
            print("{}. SMOTEENN ({:.2f}%)".format(i+1, results[r]*100))
        else:
            print("{}. Undersampled ({:.2f}%)".format(i+1, results[r]*100))

# %%
compare_results_2(df_oversampled, df_smote_tomek, df_smoteen, df_undersampled)
# Out:
# Rankings 1st is best while 4th is worst:
# 1. SMOTEENN (100.00%)
# 2. SMOTE-TOMEK (97.35%)
# 3. Oversampled (97.31%)
# 4. Undersampled (97.31%)

# %%
def compare_results(df_oversampled, df_smote_tomek, df_smoteen, df_undersampled, df_test):
    # Split the test data into features and target variable
    column_names = list(df_test.columns[:-1])
    y_test = df_test['Label'].astype('category')
    X_test = df_test[column_names]

    # Evaluate decision tree classifier on each dataset
    results = []
    for df in [df_oversampled, df_smote_tomek, df_smoteen, df_undersampled]:
        column_names = list(df.columns[:-1])
        y = df['Label'].astype('category')
        X = df[column_names]
        dectree = DecisionTreeClassifier()
        dectree.fit(X, y)
        accuracy = dectree.score(X_test, y_test)
        results.append(accuracy)

    # Rank the datasets based on their accuracy scores
    rankings = sorted(range(len(results)), key=lambda k: results[k], reverse=True)

    # Print the rankings
    print("Rankings in terms of accuracy 1st is best while 4th is worst:")
    for i, r in enumerate(rankings):
        if r == 0:
            print("{}. Oversampled ({:.2f}%)".format(i+1, results[r]*100))
        elif r == 1:
            print("{}. SMOTE-TOMEK ({:.2f}%)".format(i+1, results[r]*100))
        elif r == 2:
            print("{}. SMOTEENN ({:.2f}%)".format(i+1, results[r]*100))
        else:
            print("{}. Undersampled ({:.2f}%)".format(i+1, results[r]*100))

# %%
compare_results(df_oversampled, df_smote_tomek, df_smoteen, df_undersampled,df_test)
# Out:
# Rankings in terms of accuracy 1st is best while 4th is worst:
# 1. Undersampled (92.37%)
# 2. Oversampled (92.17%)
# 3. SMOTE-TOMEK (91.50%)
# 4. SMOTEENN (89.18%)

# %% [markdown]
# **note accuracy may not be the ideal metric in this case(explained further later)**

# %%
def visualize_preds_2(metrics_table, y_true, y_pred, name):
    # Calculate the evaluation metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    
    # Calculate the False Positive Rate
    cm = confusion_matrix(y_true, y_pred)
    FP = cm.sum(axis=0) - np.diag(cm)  # Sum of False Positives for each class
    FN = cm.sum(axis=1) - np.diag(cm)  # Sum of False Negatives for each class
    TP = np.diag(cm)  # Sum of True Positives for each class
    TN = cm.sum() - (FP + FN + TP)  # Sum of True Negatives for each class

    # Calculate the False Positive Rate
    FPR = FP / (FP + TN)
    
    # Calculate the average False Positive Rate (weighted by the support)
    avg_FPR = np.average(FPR, weights=np.bincount(y_true))

    # Add the evaluation metrics to the metrics_table
    metrics_table[name] = [accuracy, precision, recall, f1, avg_FPR]

    return metrics_table

# %%
def evaluate_dt_2(train_datasets, df_test, dataset_names):
    test_metrics_table = pd.DataFrame()
    
    for df_train, name in zip(train_datasets, dataset_names):
        # Split the data into features and target variable
        column_names = list(df_train.columns[:-1])
        y_train = df_train['Label'].astype('category')
        X_train = df_train[column_names]

        y_test = df_test['Label'].astype('category')
        X_test = df_test[column_names]

        # Train a decision tree classifier
        dectree = DecisionTreeClassifier()
        dectree.fit(X_train, y_train)

        # Make predictions on the training and test data
        y_train_pred = dectree.predict(X_train)
        y_test_pred = dectree.predict(X_test)

        # Call the visualize_preds_2 function to calculate metrics for test datasets
        test_metrics_table = visualize_preds_2(test_metrics_table, y_test, y_test_pred, f"Decision Tree Classifier - {name}")

    test_metrics_table.columns = dataset_names
    test_metrics_table.index = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'False Positive Rate']

    return test_metrics_table

# %% [markdown]
# **Running code multiple times to see the different results**

# %%
# Prepare the training datasets and their names
train_datasets = [df_oversampled, df_smote_tomek, df_smoteen, df_undersampled]
dataset_names = ["Oversampled", "SMOTE-TOMEK", "SMOTEENN", "Undersampled"]


for i in range(5):
    # Evaluate the datasets with the decision tree classifier
    result_table = evaluate_dt_2(train_datasets, df_test, dataset_names)

    # Print the result table
    print("Metrics for the test model:")
    print("\n")
    print(result_table)
# Out:
# Metrics for the test model:
#
#
#                      Oversampled  SMOTE-TOMEK  SMOTEENN  Undersampled
# Accuracy                0.923671     0.919807  0.889855      0.922705
# Precision               0.931730     0.926167  0.908435      0.931044
# Recall                  0.923671     0.919807  0.889855      0.922705
# F1 Score                0.925404     0.921371  0.893531      0.924489
# False Positive Rate     0.061636     0.076158  0.078838      0.062004
# Metrics for the test model:
#
#
#                      Oversampled  SMOTE-TOMEK  SMOTEENN  Undersampled
# Accuracy                0.925604     0.915942  0.885990      0.925604
# Precision               0.933115     0.922882  0.905443      0.933115
# Recall                  0.925604     0.915942  0.885990      0.925604
# F1 Score                0.927234     0.917650  0.889863      0.927234
# False Positive Rate     0.060902     0.079802  0.082482      0.060902
# Metrics for the test model:
#
#
# ...

# %%
def plot_metrics(metrics_table, title):
    metrics_table.T.plot(kind='bar', figsize=(10, 6))
    plt.title(title)
    plt.xlabel('Datasets')
    plt.ylabel('Metric Value')
    plt.legend(loc='best')
    plt.xticks(rotation=45)
    plt.show()

# %%
result_table = evaluate_dt_2(train_datasets, df_test, dataset_names)
plot_metrics(result_table, 'Decision Tree Classifier Metrics')

# %% [markdown]
# for clearer visual on precision and FPR

# %%
def plot_selected_metrics(metrics_table, selected_metrics, title):
    selected_table = metrics_table.loc[selected_metrics].T
    selected_table.plot(kind='bar', figsize=(10, 6))
    plt.title(title)
    plt.xlabel('Datasets')
    plt.ylabel('Metric Value')
    plt.legend(loc='best')
    plt.xticks(rotation=45)
    
    plt.show()


selected_metrics = ['False Positive Rate', 'Precision']

plot_selected_metrics(dt_metrics_table, selected_metrics, 'Decision Tree Classifier: False Positive Rate and Precision')

# %% [markdown]
# # Comparison

# %% [markdown]
# #

# %% [markdown]
# Undersampling involves randomly removing samples from the majority class to balance the dataset. In this case, it resulted in the highest accuracy. It's possible that the undersampled dataset retained enough representative samples of the majority class, leading to a model with better generalization capabilities when tested on the unseen df_test dataset.
#
# Oversampling involves adding more instances of the minority class by replicating existing samples. This approach resulted in slightly lower accuracy compared to undersampling. It's possible that oversampling led to overfitting, causing the model to perform slightly worse on the test dataset.
#
# SMOTE-TOMEK combines the SMOTE technique, which generates synthetic samples of the minority class, with Tomek Links, which removes samples that are difficult to classify. In this case, the combination of these two techniques led to a slightly lower accuracy compared to the first two methods. The synthetic samples generated by SMOTE might not have accurately represented the underlying distribution of the minority class, leading to a less accurate model.
#
# SMOTEEN is another combination of techniques, using SMOTE for oversampling and the Edited Nearest Neighbors (ENN) method for undersampling. The lower accuracy of the model trained on the SMOTEENN dataset might be due to the ENN method removing too many samples or the SMOTE method generating less representative synthetic samples. This could result in a model with weaker generalization capabilities when tested on the df_test dataset.
#
# As shown earlier,model trained with SMOTEENN data led to overfitting which could lead to lack of generalization.A perfect accuracy on the training data might indicate that the model has not learned the general patterns and relationships between the features and the target variable. Instead, it has memorized the training data, which will not be helpful when making predictions on new data(thus the 88.79% for SMOTEENN)

# %% [markdown]
# # Evaluation

# %% [markdown]
# In our opinion,a false positive is so much more detrimental and an important factor comapred to false negatives.False positives,which means **non spam emails classified as spam could lead to important emails being filtered out as spam**
# causing these emails to be missed.Therefore,**precision** is much **more important than accuracy,recall and f1 score** in this context for classifying emails as spam or not spam as false positives are more costly than false negatives.
#
# The best precision score is very for both over and undersampled datasets,**however the metrics for these 2 datasets roughly all the same.This similarity in metrics could be because the process of under and over sampling may not introduce any new information or patterns into the dataset that the model can learn from.**
#
# It is hard to tell which is better under or over sampling when using decision tree as a classifier,more advanced models such as random forest classifier can thus be used to get a better grasp of which dataset is better to train our model.
